# %%
import plotly_express as px

# %%
data = [[0, ]]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

ax.patch.set_facecolor('#2b3e50')
plt.arrow(0, 0, 0, 3, color='g', width=.07, head_width=.0001, head_length=.0001)
plt.arrow(-.2,2, .2, 1, color='g', width=.07, head_width=.0001, head_length=.0001)
plt.arrow(.2, 2, -.2, 1, color='g', width=.07, head_width=.0001, head_length=.0001)
plt.xlim(-1,1)
plt.ylim(0, 5);

# %%
fig, ax = plt.subplots()

ax.patch.set_facecolor('#2b3e50')
plt.arrow(0, 4, 0, -3, color='r', width=.07, head_width=.0001, head_length=.0001)
plt.arrow(-.2, 2, .2, -1, color='r', width=.07, head_width=.0001, head_length=.0001)
plt.arrow(.2, 2, -.2, -1, color='r', width=.07, head_width=.0001, head_length=.0001)
plt.xlim(-1,1)
plt.ylim(0, 5);
